# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set_style("darkgrid") #set style for seaborn
pd.set_option('display.max_columns', None) #show all columns pandas

#get wd
import os
os.getcwd()
# Out:
# 'c:\\Users\\menyh\\Documents\\kaggle_handm'

# %% [markdown]
# # Read in files

# %%
articles = pd.read_csv('data/articles.csv')
customers = pd.read_csv('data/customers.csv')
transactions = pd.read_csv('data/transactions_train.csv')

# %%
articles
# Out:
#         article_id  product_code               prod_name  product_type_no  \
# 0        108775015        108775               Strap top              253
# 1        108775044        108775               Strap top              253
# 2        108775051        108775           Strap top (1)              253
# 3        110065001        110065       OP T-shirt (Idro)              306
# 4        110065002        110065       OP T-shirt (Idro)              306
# ...            ...           ...                     ...              ...
# 105537   953450001        953450  5pk regular Placement1              302
# 105538   953763001        953763       SPORT Malaga tank              253
# 105539   956217002        956217         Cartwheel dress              265
# 105540   957375001        957375        CLAIRE HAIR CLAW               72
# 105541   959461001        959461            Lounge dress              265
#
#        product_type_name  product_group_name  graphical_appearance_no  \
# ...

# %%
articles['article_id'].nunique() #each article has a unique id
# Out:
# 105542

# %%
def see_variable_distribution(df, variable):
    
    count_data = df.groupby([variable]).agg(nr_of=(variable, 'count')).reset_index()
    #order dataframe by nr_of
    count_data = count_data.sort_values(by=['nr_of'], ascending=False).reset_index(drop=True)

    return count_data

# %%
see_variable_distribution(articles, 'product_type_name')
# Out:
#     product_type_name  nr_of
# 0            Trousers  11169
# 1               Dress  10362
# 2             Sweater   9302
# 3             T-shirt   7904
# 4                 Top   4155
# ..                ...    ...
# 126      Bra extender      1
# 127           Blanket      1
# 128             Towel      1
# 129        Wood balls      1
# 130           Cushion      1
#
# [131 rows x 2 columns]

# %%
customers
# Out:
#                                                customer_id   FN  Active  \
# 0        00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1        0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2        000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3        00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4        00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
# ...                                                    ...  ...     ...
# 1371975  ffffbbf78b6eaac697a8a5dfbfd2bfa8113ee5b403e474...  NaN     NaN
# 1371976  ffffcd5046a6143d29a04fb8c424ce494a76e5cdf4fab5...  NaN     NaN
# 1371977  ffffcf35913a0bee60e8741cb2b4e78b8a98ee5ff2e6a1...  1.0     1.0
# 1371978  ffffd7744cebcf3aca44ae7049d2a94b87074c3d4ffe38...  1.0     1.0
# 1371979  ffffd9ac14e89946416d80e791d064701994755c3ab686...  NaN     NaN
#
#         club_member_status fashion_news_frequency   age  \
# ...

# %%
customers['customer_id'].nunique() #each customer has unique ID
# Out:
# 1371980

# %%
def plot_continous_histogram(df, variable, binwidth=1):
    #set title sns
    sns.displot(df[variable], binwidth=binwidth)
    plt.title(str("Distribution of the: " + variable + " variable"))
    plt.show()

# %%
plot_continous_histogram(customers, 'age')

# %%
transactions
# Out:
#                t_dat                                        customer_id  \
# 0         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1         2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 2         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 3         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# 4         2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...
# ...              ...                                                ...
# 31788319  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788320  2020-09-22  fff2282977442e327b45d8c89afde25617d00124d0f999...
# 31788321  2020-09-22  fff380805474b287b05cb2a7507b9a013482f7dd0bce0e...
# 31788322  2020-09-22  fff4d3a8b1f3b60af93e78c30a7cb4cf75edaf2590d3e5...
# 31788323  2020-09-22  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#           article_id     price  sales_channel_id
# 0          663713001  0.050831                 2
# ...

# %%
transaction_daily =  transactions.groupby(['t_dat']).agg(nr_of=('price', 'count'), value = ('price', 'sum')).reset_index()
transaction_daily = transaction_daily.sort_values(by=['t_dat'], ascending=True).reset_index(drop=True)
transaction_daily['t_dat'] = pd.to_datetime(transaction_daily['t_dat'], format = '%Y-%m-%d')
# calculate weekly total sales
# round date to nearest week
transaction_daily['data_week'] = transaction_daily['t_dat'] - pd.to_timedelta(transaction_daily['t_dat'].dt.dayofweek, unit='d')
transaction_weekly =  transaction_daily.groupby(['data_week']).agg(nr_of=('value', 'count'), value = ('value', 'sum')).reset_index()
transaction_weekly
# Out:
#      data_week  nr_of         value
# 0   2018-09-17      4   4958.828864
# 1   2018-09-24      7  12796.810729
# 2   2018-10-01      7   7927.243119
# 3   2018-10-08      7   9792.129814
# 4   2018-10-15      7   8926.345559
# ..         ...    ...           ...
# 101 2020-08-24      7   8883.000271
# 102 2020-08-31      7   8554.538339
# 103 2020-09-07      7   9280.541593
# 104 2020-09-14      7   7932.859949
# 105 2020-09-21      2   2273.016475
#
# [106 rows x 3 columns]

# %%
# sns time series plot
sns.lineplot(x='data_week', y='value', data=transaction_weekly)
# Out:
# <AxesSubplot:xlabel='data_week', ylabel='value'>

# %% [markdown]
# ## Find top customers - count how many multiple purchases we have

# %%
count_purchase = transactions.groupby(['customer_id']).agg(nr_of=('price', 'count'), value = ('price', 'sum')).reset_index()

# %%
count_purchase = count_purchase.sort_values(by=['nr_of'], ascending=False).reset_index(drop=True)
# log value
count_purchase['log_nr_of'] = np.log(count_purchase['nr_of'])
count_purchase
# Out:
#                                                customer_id  nr_of      value  \
# 0        be1981ab818cf4ef6765b2ecaea7a2cbf14ccd6e8a7ee9...   1895  57.676407
# 1        b4db5e5259234574edfff958e170fe3a5e13b6f146752c...   1441  47.662000
# 2        49beaacac0c7801c2ce2d189efe525fe80b5d37e46ed05...   1364  30.126814
# 3        a65f77281a528bf5c1e9f270141d601d116e1df33bf9df...   1361  50.921186
# 4        cd04ec2726dd58a8c753e0d6423e57716fd9ebcf2f14ed...   1237  41.327051
# ...                                                    ...    ...        ...
# 1362276  f678b66d6b01ec5c3d2c8e68e70e7f93cdd285bc8c2b0e...      1   0.033881
# 1362277  5bb229ffff01d8952588a1e2e0ec9e8f0d4f0b4d626c1a...      1   0.015237
# 1362278  6c9b8e09d39540927fbf1ecbb79737296383b2f6eb519e...      1   0.042356
# 1362279  48ffc933cceba6f768a218dde7179928c8ef42392eda55...      1   0.019695
# 1362280  ffffd9ac14e89946416d80e791d064701994755c3ab686...      1   0.084729
#
#          log_nr_of
# 0         7.546974
# ...

# %%
plot_continous_histogram(count_purchase[count_purchase['nr_of'] < 100], 'nr_of', binwidth=5)

# %%
plot_continous_histogram(count_purchase, 'log_nr_of', binwidth=1)
